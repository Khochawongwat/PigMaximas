# %%
import utils
import importlib
import cv2 as cv
import matplotlib.pyplot as plt

importlib.reload(utils)

img = cv.imread("demos\demoA.png")
sections = utils.section(img)

plt.figure(figsize=(12, 6))

plt.subplot(1, len(sections) + 1, 1)
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title("Image")
plt.axis("off")

for i, section in enumerate(sections):
    plt.subplot(1, len(sections) + 1, i + 2)
    plt.imshow(cv.cvtColor(section, cv.COLOR_BGR2RGB))
    plt.title(f"Section {i + 1}")
    plt.axis("off")

plt.tight_layout() 
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Tawan\AppData\Local\Temp\ipykernel_45596\4146923335.py:8: SyntaxWarning: invalid escape sequence '\d'
#   img = cv.imread("demos\demoA.png")
# C:\Users\Tawan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\interpolate\_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# C:\Users\Tawan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\interpolate\_interpolate.py:715: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# d:\Workspace\PigMaximas\utils.py:129: RuntimeWarning: invalid value encountered in cast
#   (np.round(y_new).astype(int), x_new.astype(int))
